# %%
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
import warnings
warnings.filterwarnings(action='ignore')
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\82109\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
dataset=pd.read_csv("Dry_Bean_Dataset.csv")
dataset
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0          0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1          0.411785       29172     191.272751  0.783968  0.984986   0.887034
# 2          0.562727       29690     193.410904  0.778113  0.989559   0.947849
# 3          0.498616       30724     195.467062  0.782681  0.976696   0.903936
# 4          0.333680       30417     195.896503  0.773098  0.990893   0.984877
# ...             ...         ...            ...       ...       ...        ...
# 13606      0.765002       42508     231.515799  0.714574  0.990331   0.916603
# 13607      0.735702       42494     231.526798  0.799943  0.990752   0.922015
# 13608      0.734065       42569     231.631261  0.729932  0.989899   0.918424
# 13609      0.741055       42667     231.653247  0.705389  0.987813   0.907906
# 13610      0.786693       42600     231.686223  0.788962  0.989648   0.888380
#
#        Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  \
# 0         0.913358      0.007332      0.003147      0.834222      0.998724
# 1         0.953861      0.006979      0.003564      0.909851      0.998430
# 2         0.908774      0.007244      0.003048      0.825871      0.999066
# 3         0.928329      0.007017      0.003215      0.861794      0.994199
# 4         0.970516      0.006697      0.003665      0.941900      0.999166
# ...            ...           ...           ...           ...           ...
# 13606     0.801865      0.006858      0.001749      0.642988      0.998385
# 13607     0.822252      0.006688      0.001886      0.676099      0.998219
# 13608     0.822730      0.006681      0.001888      0.676884      0.996767
# 13609     0.817457      0.006724      0.001852      0.668237      0.995222
# 13610     0.784997      0.007001      0.001640      0.616221      0.998180
#
#           Class
# 0         SEKER
# 1         SEKER
# 2         SEKER
# 3         SEKER
# 4         SEKER
# ...         ...
# 13606  DERMASON
# 13607  DERMASON
# 13608  DERMASON
# 13609  DERMASON
# 13610  DERMASON
#
# [13611 rows x 17 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
#  16  Class            13611 non-null  object
# dtypes: float64(14), int64(2), object(1)
# memory usage: 1.8+ MB

# %%
dataset.isnull().sum()
# Out:
# Area               0
# Perimeter          0
# MajorAxisLength    0
# MinorAxisLength    0
# AspectRation       0
# Eccentricity       0
# ConvexArea         0
# EquivDiameter      0
# Extent             0
# Solidity           0
# roundness          0
# Compactness        0
# ShapeFactor1       0
# ShapeFactor2       0
# ShapeFactor3       0
# ShapeFactor4       0
# Class              0
# dtype: int64

# %%
plt.figure(figsize = (8, 5))
sns.countplot(x =dataset["Class"], palette="Set2")
plt.title("Number of beans per type")
plt.show()

# %%
dataset['Class'].value_counts()
# Out:
# DERMASON    3546
# SIRA        2636
# SEKER       2027
# HOROZ       1928
# CALI        1630
# BARBUNYA    1322
# BOMBAY       522
# Name: Class, dtype: int64

# %%
X = dataset.iloc[:,0:16].values
y = dataset['Class']

from sklearn.preprocessing import LabelEncoder
encoder =  LabelEncoder()
y1 = encoder.fit_transform(y)

Y = pd.get_dummies(y1).values

from sklearn.model_selection import train_test_split

X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
scaler_X = preprocessing.StandardScaler().fit(X_train)
X_train= scaler_X.transform(X_train)
X_test = scaler_X.transform(X_test)

# %%
print("X_train.shape:", X_train.shape)

print("y_train.shape:", y_train.shape)

print("X_test.shape:", X_test.shape)

print("y_test.shape:", y_test.shape)
# Out:
# X_train.shape: (10888, 16)
# y_train.shape: (10888, 7)
# X_test.shape: (2723, 16)
# y_test.shape: (2723, 7)

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from keras.optimizers import SGD, Adam

# %%
def build_model(): 
    model = models.Sequential()
    model.add(layers.Dense(64, activation='ReLU', input_shape=(16,)))
    model.add(layers.Dense(32, activation='ReLU'))
    model.add(layers.Dense(16, activation='ReLU'))
    model.add(layers.Dense(7, activation='softmax'))
    model.compile(Adam(lr=0.00048), 'categorical_crossentropy', metrics=['accuracy'])
    
    return model


model = build_model() 

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                1088
#
#  dense_9 (Dense)             (None, 32)                2080
#
#  dense_10 (Dense)            (None, 16)                528
#
#  dense_11 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 3,815
# Trainable params: 3,815
# Non-trainable params: 0
# _________________________________________________________________

# %%
#fitting the model and predicting 
# fit network
model_history=model.fit(x=X_train, y=y_train, epochs=100, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/100
# 341/341 [==============================] - 2s 3ms/step - loss: 0.7913 - accuracy: 0.7743 - val_loss: 0.3499 - val_accuracy: 0.8935
# Epoch 2/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.2843 - accuracy: 0.9052 - val_loss: 0.2326 - val_accuracy: 0.9203
# Epoch 3/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.2266 - accuracy: 0.9190 - val_loss: 0.2135 - val_accuracy: 0.9258
# Epoch 4/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.2090 - accuracy: 0.9236 - val_loss: 0.2056 - val_accuracy: 0.9302
# Epoch 5/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.2030 - accuracy: 0.9232 - val_loss: 0.2002 - val_accuracy: 0.9291
# Epoch 6/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1983 - accuracy: 0.9256 - val_loss: 0.1965 - val_accuracy: 0.9302
# Epoch 7/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1952 - accuracy: 0.9262 - val_loss: 0.1966 - val_accuracy: 0.9335
# Epoch 8/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1928 - accuracy: 0.9259 - val_loss: 0.2022 - val_accuracy: 0.9321
# Epoch 9/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1916 - accuracy: 0.9260 - val_loss: 0.1982 - val_accuracy: 0.9280
# Epoch 10/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1894 - accuracy: 0.9276 - val_loss: 0.1938 - val_accuracy: 0.9328
# Epoch 11/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1881 - accuracy: 0.9288 - val_loss: 0.1954 - val_accuracy: 0.9306
# Epoch 12/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1873 - accuracy: 0.9288 - val_loss: 0.1928 - val_accuracy: 0.9332
# Epoch 13/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1861 - accuracy: 0.9291 - val_loss: 0.1959 - val_accuracy: 0.9328
# Epoch 14/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1845 - accuracy: 0.9300 - val_loss: 0.1970 - val_accuracy: 0.9339
# Epoch 15/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1831 - accuracy: 0.9313 - val_loss: 0.1958 - val_accuracy: 0.9335
# Epoch 16/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1826 - accuracy: 0.9297 - val_loss: 0.2018 - val_accuracy: 0.9321
# Epoch 17/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1830 - accuracy: 0.9290 - val_loss: 0.1918 - val_accuracy: 0.9335
# Epoch 18/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1804 - accuracy: 0.9314 - val_loss: 0.1925 - val_accuracy: 0.9324
# Epoch 19/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1808 - accuracy: 0.9311 - val_loss: 0.1942 - val_accuracy: 0.9313
# Epoch 20/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1800 - accuracy: 0.9324 - val_loss: 0.1907 - val_accuracy: 0.9354
# Epoch 21/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1784 - accuracy: 0.9319 - val_loss: 0.1902 - val_accuracy: 0.9354
# Epoch 22/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1789 - accuracy: 0.9307 - val_loss: 0.1893 - val_accuracy: 0.9339
# Epoch 23/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1779 - accuracy: 0.9308 - val_loss: 0.2001 - val_accuracy: 0.9284
# Epoch 24/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1779 - accuracy: 0.9319 - val_loss: 0.1889 - val_accuracy: 0.9346
# Epoch 25/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1762 - accuracy: 0.9332 - val_loss: 0.1888 - val_accuracy: 0.9346
# Epoch 26/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1763 - accuracy: 0.9314 - val_loss: 0.1942 - val_accuracy: 0.9332
# Epoch 27/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1767 - accuracy: 0.9321 - val_loss: 0.1878 - val_accuracy: 0.9350
# Epoch 28/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1756 - accuracy: 0.9331 - val_loss: 0.1890 - val_accuracy: 0.9350
# Epoch 29/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1742 - accuracy: 0.9335 - val_loss: 0.1919 - val_accuracy: 0.9299
# Epoch 30/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1752 - accuracy: 0.9330 - val_loss: 0.1874 - val_accuracy: 0.9335
# Epoch 31/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1742 - accuracy: 0.9319 - val_loss: 0.1905 - val_accuracy: 0.9324
# Epoch 32/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1742 - accuracy: 0.9333 - val_loss: 0.2061 - val_accuracy: 0.9288
# Epoch 33/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1738 - accuracy: 0.9337 - val_loss: 0.1950 - val_accuracy: 0.9339
# Epoch 34/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1728 - accuracy: 0.9322 - val_loss: 0.1875 - val_accuracy: 0.9354
# Epoch 35/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1730 - accuracy: 0.9346 - val_loss: 0.1963 - val_accuracy: 0.9339
# Epoch 36/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1717 - accuracy: 0.9352 - val_loss: 0.1893 - val_accuracy: 0.9332
# Epoch 37/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1712 - accuracy: 0.9363 - val_loss: 0.1916 - val_accuracy: 0.9324
# Epoch 38/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1718 - accuracy: 0.9336 - val_loss: 0.1882 - val_accuracy: 0.9343
# Epoch 39/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1716 - accuracy: 0.9353 - val_loss: 0.1897 - val_accuracy: 0.9335
# Epoch 40/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1704 - accuracy: 0.9332 - val_loss: 0.1944 - val_accuracy: 0.9324
# Epoch 41/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1696 - accuracy: 0.9353 - val_loss: 0.1857 - val_accuracy: 0.9346
# Epoch 42/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1694 - accuracy: 0.9358 - val_loss: 0.1916 - val_accuracy: 0.9339
# Epoch 43/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1684 - accuracy: 0.9351 - val_loss: 0.1883 - val_accuracy: 0.9361
# Epoch 44/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1703 - accuracy: 0.9341 - val_loss: 0.1882 - val_accuracy: 0.9365
# Epoch 45/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1688 - accuracy: 0.9352 - val_loss: 0.1877 - val_accuracy: 0.9361
# Epoch 46/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1682 - accuracy: 0.9362 - val_loss: 0.1883 - val_accuracy: 0.9350
# Epoch 47/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1672 - accuracy: 0.9332 - val_loss: 0.1933 - val_accuracy: 0.9346
# Epoch 48/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1676 - accuracy: 0.9358 - val_loss: 0.1873 - val_accuracy: 0.9354
# Epoch 49/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1692 - accuracy: 0.9360 - val_loss: 0.1860 - val_accuracy: 0.9379
# Epoch 50/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1677 - accuracy: 0.9364 - val_loss: 0.1907 - val_accuracy: 0.9346
# Epoch 51/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1677 - accuracy: 0.9356 - val_loss: 0.1871 - val_accuracy: 0.9387
# Epoch 52/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1667 - accuracy: 0.9361 - val_loss: 0.1887 - val_accuracy: 0.9357
# Epoch 53/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1672 - accuracy: 0.9351 - val_loss: 0.1922 - val_accuracy: 0.9328
# Epoch 54/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1653 - accuracy: 0.9379 - val_loss: 0.1894 - val_accuracy: 0.9343
# Epoch 55/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1653 - accuracy: 0.9375 - val_loss: 0.1887 - val_accuracy: 0.9346
# Epoch 56/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1649 - accuracy: 0.9371 - val_loss: 0.1862 - val_accuracy: 0.9383
# Epoch 57/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1654 - accuracy: 0.9356 - val_loss: 0.1897 - val_accuracy: 0.9361
# Epoch 58/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1650 - accuracy: 0.9374 - val_loss: 0.1878 - val_accuracy: 0.9354
# Epoch 59/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1629 - accuracy: 0.9380 - val_loss: 0.1944 - val_accuracy: 0.9379
# Epoch 60/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1648 - accuracy: 0.9353 - val_loss: 0.1916 - val_accuracy: 0.9357
# Epoch 61/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1633 - accuracy: 0.9375 - val_loss: 0.1893 - val_accuracy: 0.9379
# Epoch 62/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1634 - accuracy: 0.9375 - val_loss: 0.1962 - val_accuracy: 0.9339
# Epoch 63/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1627 - accuracy: 0.9369 - val_loss: 0.1923 - val_accuracy: 0.9328
# Epoch 64/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1635 - accuracy: 0.9367 - val_loss: 0.1903 - val_accuracy: 0.9383
# Epoch 65/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1619 - accuracy: 0.9390 - val_loss: 0.1882 - val_accuracy: 0.9376
# Epoch 66/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1631 - accuracy: 0.9378 - val_loss: 0.1911 - val_accuracy: 0.9379
# Epoch 67/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1617 - accuracy: 0.9371 - val_loss: 0.1958 - val_accuracy: 0.9350
# Epoch 68/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1624 - accuracy: 0.9375 - val_loss: 0.1883 - val_accuracy: 0.9376
# Epoch 69/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1621 - accuracy: 0.9371 - val_loss: 0.1883 - val_accuracy: 0.9379
# Epoch 70/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1609 - accuracy: 0.9375 - val_loss: 0.1919 - val_accuracy: 0.9357
# Epoch 71/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1608 - accuracy: 0.9390 - val_loss: 0.1912 - val_accuracy: 0.9365
# Epoch 72/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1603 - accuracy: 0.9377 - val_loss: 0.1916 - val_accuracy: 0.9365
# Epoch 73/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1603 - accuracy: 0.9390 - val_loss: 0.1931 - val_accuracy: 0.9383
# Epoch 74/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1596 - accuracy: 0.9398 - val_loss: 0.1868 - val_accuracy: 0.9383
# Epoch 75/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1595 - accuracy: 0.9383 - val_loss: 0.1927 - val_accuracy: 0.9350
# Epoch 76/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1587 - accuracy: 0.9405 - val_loss: 0.1927 - val_accuracy: 0.9361
# Epoch 77/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1595 - accuracy: 0.9383 - val_loss: 0.1925 - val_accuracy: 0.9368
# Epoch 78/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1592 - accuracy: 0.9390 - val_loss: 0.1872 - val_accuracy: 0.9350
# Epoch 79/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1583 - accuracy: 0.9381 - val_loss: 0.1894 - val_accuracy: 0.9383
# Epoch 80/100
# 341/341 [==============================] - 1s 2ms/step - loss: 0.1587 - accuracy: 0.9395 - val_loss: 0.1883 - val_accuracy: 0.9368
# Epoch 81/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1576 - accuracy: 0.9395 - val_loss: 0.1871 - val_accuracy: 0.9376
# Epoch 82/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1583 - accuracy: 0.9398 - val_loss: 0.1911 - val_accuracy: 0.9350
# Epoch 83/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1590 - accuracy: 0.9380 - val_loss: 0.1994 - val_accuracy: 0.9350
# Epoch 84/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1566 - accuracy: 0.9379 - val_loss: 0.1896 - val_accuracy: 0.9390
# Epoch 85/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1578 - accuracy: 0.9396 - val_loss: 0.1921 - val_accuracy: 0.9372
# Epoch 86/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1585 - accuracy: 0.9389 - val_loss: 0.1929 - val_accuracy: 0.9350
# Epoch 87/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1575 - accuracy: 0.9386 - val_loss: 0.1911 - val_accuracy: 0.9368
# Epoch 88/100
# 341/341 [==============================] - 1s 2ms/step - loss: 0.1573 - accuracy: 0.9398 - val_loss: 0.2003 - val_accuracy: 0.9339
# Epoch 89/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1570 - accuracy: 0.9413 - val_loss: 0.1902 - val_accuracy: 0.9401
# Epoch 90/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1566 - accuracy: 0.9403 - val_loss: 0.1987 - val_accuracy: 0.9361
# Epoch 91/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1560 - accuracy: 0.9398 - val_loss: 0.1871 - val_accuracy: 0.9357
# Epoch 92/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1552 - accuracy: 0.9411 - val_loss: 0.1895 - val_accuracy: 0.9398
# Epoch 93/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1560 - accuracy: 0.9409 - val_loss: 0.1887 - val_accuracy: 0.9387
# Epoch 94/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1560 - accuracy: 0.9399 - val_loss: 0.1933 - val_accuracy: 0.9357
# Epoch 95/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1556 - accuracy: 0.9401 - val_loss: 0.1949 - val_accuracy: 0.9354
# Epoch 96/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1554 - accuracy: 0.9413 - val_loss: 0.1860 - val_accuracy: 0.9390
# Epoch 97/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1555 - accuracy: 0.9401 - val_loss: 0.1909 - val_accuracy: 0.9357
# Epoch 98/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1546 - accuracy: 0.9409 - val_loss: 0.1913 - val_accuracy: 0.9343
# Epoch 99/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1557 - accuracy: 0.9401 - val_loss: 0.1995 - val_accuracy: 0.9343
# Epoch 100/100
# 341/341 [==============================] - 1s 3ms/step - loss: 0.1544 - accuracy: 0.9414 - val_loss: 0.1956 - val_accuracy: 0.9361
# 86/86 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss = model_history.history['loss']
val_loss = model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.89      0.94       255
#            1       1.00      0.99      0.99        92
#            2       0.92      0.97      0.95       350
#            3       0.91      0.95      0.93       735
#            4       0.96      0.96      0.96       390
#            5       0.97      0.97      0.97       376
#            6       0.90      0.87      0.88       525
#
#     accuracy                           0.94      2723
#    macro avg       0.95      0.94      0.95      2723
# weighted avg       0.94      0.94      0.94      2723
#
# [[227   0  20   0   1   2   5]
#  [  0  91   1   0   0   0   0]
#  [  2   0 339   0   6   1   2]
#  [  0   0   0 699   1   7  28]
#  [  0   0   6   2 374   0   8]
#  [  0   0   0   3   0 364   9]
#  [  0   0   1  60   8   1 455]]
